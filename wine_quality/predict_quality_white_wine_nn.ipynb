# %% [markdown]
# # Overview #
#
# The objective of this task is to build a model that predicts the quality of red wine given certain features. Wine quality ranges from 0 (poor) to 10 (excellent).

# %% [markdown]
# # Import libraries & define some variables #

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

TRAIN_DATASET = os.path.join('dataset', 'winequality_white.csv')

# %% [markdown]
# # Data Inspection and Preprocessing #

# %%
data = pd.read_csv(TRAIN_DATASET)
df = data.copy()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# Luckily, this dataset does not have any `NaN` values and all inputs are numeric.

# %% [markdown]
# # Exploratory Data Analysis #

# %%
plt.figure(figsize=(8, 8))
plt.hist(df['quality'], range=(0, 10))
plt.xlabel('Wine Quality')
plt.show()

# %% [markdown]
# Most of the red wine samples provided fall between 5 and 7; meaning that they are mostly good wine (not excellent). This could affect the strength of prediction of the model since it will learn more of what makes red wine good.
#
# Studying the correlation between the features will give an idea of what features really affect wine quality positively or negatively.

# %%
def heatmap(df):
    plt.figure(figsize=(12, 12))
    sns.set(font_scale=1.5)
    sns.heatmap(df.corr(), cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 14}, yticklabels=df.columns, 
                xticklabels=df.columns)
    plt.show()
    
heatmap(df)

# %% [markdown]
# We will exam features with strong correlation (>=0.43) between them.

# %%
corr_cols = ['fixed acidity', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 
             'alcohol', 'quality']

def pairplot(cols):
    sns.pairplot(df[cols])
    plt.show()
    
pairplot(corr_cols)

# %% [markdown]
# # Looking out for outliers #
#
# The approach to be applied to looking for outliers will be to compare correlations between features and view the plot of points between these correlations. Correlation values greater than 0.5 and have "eye-balled" outliers from the pairplot will be analyzed.

# %%
from scipy import stats
from scipy.optimize import curve_fit
from numpy.polynomial.polynomial import polyfit
import random

def plot_relationship_best_fit(x_axis, x_label, y_axis, y_label, best_fit='linear'):
    fit = None
    
    if best_fit == 'linear':
        slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)
        fit = slope * x_axis + intercept
#         c = polyfit(x_axis, y_axis, 1)
#         fit = c[0] + c[1]*x_axis
    
    if best_fit == 'quadratic':
        popt, pcov = curve_fit(func, x_axis, y_axis)
        fit = func(x_axis, *popt)
        
#         coef = polyfit(x_axis, y_axis, 2)
#         fit = coef[0] + coef[1]*x_axis + coef[2]*(x_axis**2)
        
    np.random.seed(42)
    r = random.randint(0, len(x_axis)-1)
    
    plt.figure(figsize=(8,8))    
    plt.scatter(x_axis, y_axis)
    plt.plot(x_axis, fit, color='r')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    
def func(x, a, b, c):
    return a*(x**2) + b*x + c

# %%
def corr_plot(x_axis, x_label, y_axis, y_label, title=None, legend=None):
    plt.figure(figsize=(8, 8))
    plt.scatter(x_axis, y_axis)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %% [markdown]
# #### Residual Sugar & Density ####

# %%
corr = 'Corr: %.2f' % df['residual sugar'].corr(df['density'])
corr_plot(df['density'], 'Density', df['residual sugar'], 'Residual Sugar', 
          'Relationship between Residual Sugar and Density ({})'.format(corr))

# %% [markdown]
# Residual sugar and density are highly positively correlated, therefore, there is no need to remove outliers.

# %% [markdown]
# #### Total Sulfur Dioxide & Density ####

# %%
corr = 'Corr: %.2f' % df['total sulfur dioxide'].corr(df['density'])
corr_plot(df['total sulfur dioxide'], 'Total Sulfur Dioxide', df['density'], 'Density', 
          'Relationship between Total Sulfur Dioxide and Density ({})'.format(corr))

# %%
plot_relationship_best_fit(df['total sulfur dioxide'], 'Total Sulfur Dioxide', df['density'], 'Density')

# %% [markdown]
# Total sulfur dioxide and density are positively correlated. Outliers can easily be "eyeballed". Density above 1.01 are too extreme cases that need to be removed. Total sulfur dioxide cases more than 300 will also be removed.

# %%
df = df[df['density'] < 1.01]
df = df[df['total sulfur dioxide'] < 300]

corr = 'Corr: %.2f' % df['total sulfur dioxide'].corr(df['density'])
corr_plot(df['total sulfur dioxide'], 'Total Sulfur Dioxide', df['density'], 'Density', 
          'Relationship between Total Sulfur Dioxide and Density ({})'.format(corr))

# %% [markdown]
# #### Density & Alcohol ####

# %%
corr = 'Corr: %.2f' % df['density'].corr(df['alcohol'])
corr_plot(df['alcohol'], 'Alcohol', df['density'], 'Density', 
          'Relationship between Density and Alcohol ({})'.format(corr))

# %%
plot_relationship_best_fit(df['alcohol'], 'Alcohol', df['density'], 'Density')

# %% [markdown]
# #### Free Sulfur Dioxide & Total Sulfur Dioxide ####

# %%
corr = 'Corr: %.2f' % df['free sulfur dioxide'].corr(df['total sulfur dioxide'])
corr_plot(df['total sulfur dioxide'], 'Total Sulfur Dioxide', df['free sulfur dioxide'], 'Free Sulfur Dioxide', 
          'Relationship between Free Sulfur Dioxide and Total Sulfur Dioxide ({})'.format(corr))

# %% [markdown]
# Free sulfur dioxide and total sulfur dioxide are positively correlated and the plot can be used as is without removing outliers.

# %%
df.shape
# Out:
# (4889, 12)

# %% [markdown]
# # Feature Engineering #
#
# Features will be engineered to create new features based on the relationship between the features and their correlation. From research, total acidity is made up of fixed acidity and volatile acidity. These features will be combined to one feature. Features that have a correlation greater than 0.4 will be combined to form new features.

# %%
df['total acidity'] = df['fixed acidity'] + df['volatile acidity']
df['alcohol density'] = df['alcohol'] * df['density']
df['residual sugar density'] = df['residual sugar'] * df['density']
df['total sulfur dioxide density'] = df['total sulfur dioxide'] * df['density']
df['sulfur dioxide content'] = df['total sulfur dioxide'] * df['free sulfur dioxide']
df['alcohol quality'] = df['alcohol'] * df['quality']

df.drop(['alcohol', 'density', 'fixed acidity', 'volatile acidity', 'total sulfur dioxide', 
         'free sulfur dioxide'], axis=1, inplace=True)

df = df.reset_index(drop=True)

# %%
from sklearn.preprocessing import PolynomialFeatures

random_state = 42
target = df['quality']
features = df.drop('quality', axis=1)

# poly = PolynomialFeatures(2)
# features = poly.fit_transform(features)
features.shape
# Out:
# (4889, 11)

# %%
df.shape
# Out:
# (4889, 12)

# %% [markdown]
# # Feature Scaling #
#
# With outliers removed, the dataset will be scaled using the `StandardScaler` class. But first the data will be split into training and testing sets with a ration of 70% to 30%.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.30, random_state=random_state)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3422, 11)
# (1467, 11)
# (3422,)
# (1467,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Train model #
#
# The model will be trained using a neural network architecture and will be evaluated using the `r2 score`. The Keras library will be used in developing the neural network architecture, compiling, training, evaluating the model and predicting wine quality. The architecture is made up of the input layer, 8 hidden layer and the output/prediction layer. Dropout is applied to the hidden layers to avoid overfitting.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(32, input_dim=X_train.shape[1]))
model.add(Activation('relu'))
model.add(Dense(218))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(512))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1024))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1024))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1024))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(512))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(218))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae', 'accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 32)                384
# _________________________________________________________________
# activation_9 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 218)               7194
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 218)               0
# _________________________________________________________________
# activation_10 (Activation)   (None, 218)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               112128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# activation_12 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# activation_13 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# activation_14 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# activation_15 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 218)               111834
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 218)               0
# _________________________________________________________________
# activation_16 (Activation)   (None, 218)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 219
# =================================================================
# Total params: 3,381,071
# Trainable params: 3,381,071
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Early stopping will be used to stop the training once there is no change in the loss. The training will stop if there is no change in loss after 250 iterations. Because of the size of the dataset, the test data will be used for validation. The model does not train on the test data.

# %%
early_stopping = EarlyStopping(patience=250)
history = model.fit(X_train, y_train, epochs=1000, verbose=1, validation_split=.3, validation_data=(X_test, y_test), 
                    callbacks=[early_stopping])
# Out:
# Train on 3422 samples, validate on 1467 samples
# Epoch 1/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 48.5045 - mean_absolute_error: 2.4322 - acc: 0.1546 - val_loss: 8.2880 - val_mean_absolute_error: 2.7689 - val_acc: 0.0130
# Epoch 2/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 3.3998 - mean_absolute_error: 1.4699 - acc: 0.2189 - val_loss: 0.6999 - val_mean_absolute_error: 0.6796 - val_acc: 0.3899
# Epoch 3/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 1.3586 - mean_absolute_error: 0.9321 - acc: 0.3282 - val_loss: 1.1459 - val_mean_absolute_error: 0.9601 - val_acc: 0.1766
# Epoch 4/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.9561 - mean_absolute_error: 0.7549 - acc: 0.4267 - val_loss: 0.1227 - val_mean_absolute_error: 0.2647 - val_acc: 0.8630
# Epoch 5/1000
# 3422/3422 [==============================] - 9s 2ms/step - loss: 0.7055 - mean_absolute_error: 0.6600 - acc: 0.4667 - val_loss: 0.3448 - val_mean_absolute_error: 0.5164 - val_acc: 0.5487
# Epoch 6/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.6109 - mean_absolute_error: 0.6026 - acc: 0.5050 - val_loss: 0.0530 - val_mean_absolute_error: 0.1654 - val_acc: 0.9509
# Epoch 7/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.5440 - mean_absolute_error: 0.5814 - acc: 0.5096 - val_loss: 0.0901 - val_mean_absolute_error: 0.2411 - val_acc: 0.9196
# Epoch 8/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.4512 - mean_absolute_error: 0.5190 - acc: 0.5754 - val_loss: 0.1486 - val_mean_absolute_error: 0.3548 - val_acc: 0.9162
# Epoch 9/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.4227 - mean_absolute_error: 0.5013 - acc: 0.5888 - val_loss: 0.0823 - val_mean_absolute_error: 0.1781 - val_acc: 0.9107
# Epoch 10/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.3796 - mean_absolute_error: 0.4807 - acc: 0.6116 - val_loss: 0.0621 - val_mean_absolute_error: 0.1835 - val_acc: 0.9400
# Epoch 11/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.3535 - mean_absolute_error: 0.4626 - acc: 0.6280 - val_loss: 0.0230 - val_mean_absolute_error: 0.1192 - val_acc: 0.9864
# Epoch 12/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.3073 - mean_absolute_error: 0.4309 - acc: 0.6552 - val_loss: 0.1121 - val_mean_absolute_error: 0.2789 - val_acc: 0.9305
# Epoch 13/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.2669 - mean_absolute_error: 0.4046 - acc: 0.6867 - val_loss: 0.0186 - val_mean_absolute_error: 0.0988 - val_acc: 0.9870
# Epoch 14/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.2824 - mean_absolute_error: 0.4110 - acc: 0.6847 - val_loss: 0.1432 - val_mean_absolute_error: 0.3472 - val_acc: 0.9318
# Epoch 15/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.2442 - mean_absolute_error: 0.3861 - acc: 0.7095 - val_loss: 0.1202 - val_mean_absolute_error: 0.2822 - val_acc: 0.9475
# Epoch 16/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.2199 - mean_absolute_error: 0.3586 - acc: 0.7507 - val_loss: 0.0321 - val_mean_absolute_error: 0.1347 - val_acc: 0.9932
# Epoch 17/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.2027 - mean_absolute_error: 0.3470 - acc: 0.7607 - val_loss: 0.0759 - val_mean_absolute_error: 0.2078 - val_acc: 0.9312
# Epoch 18/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1958 - mean_absolute_error: 0.3447 - acc: 0.7615 - val_loss: 0.0290 - val_mean_absolute_error: 0.0931 - val_acc: 0.9673
# Epoch 19/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.1977 - mean_absolute_error: 0.3435 - acc: 0.7627 - val_loss: 0.0738 - val_mean_absolute_error: 0.1907 - val_acc: 0.9339
# Epoch 20/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1759 - mean_absolute_error: 0.3234 - acc: 0.7905 - val_loss: 0.1406 - val_mean_absolute_error: 0.3466 - val_acc: 0.9284
# Epoch 21/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1742 - mean_absolute_error: 0.3252 - acc: 0.7881 - val_loss: 0.0258 - val_mean_absolute_error: 0.0947 - val_acc: 0.9755
# Epoch 22/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1743 - mean_absolute_error: 0.3262 - acc: 0.7855 - val_loss: 0.0222 - val_mean_absolute_error: 0.0980 - val_acc: 0.9686
# Epoch 23/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.1699 - mean_absolute_error: 0.3192 - acc: 0.7960 - val_loss: 0.0195 - val_mean_absolute_error: 0.1147 - val_acc: 0.9884
# Epoch 24/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1648 - mean_absolute_error: 0.3141 - acc: 0.8033 - val_loss: 0.0163 - val_mean_absolute_error: 0.0667 - val_acc: 0.9761
# Epoch 25/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.1624 - mean_absolute_error: 0.3128 - acc: 0.8054 - val_loss: 0.0129 - val_mean_absolute_error: 0.0952 - val_acc: 0.9952
# Epoch 26/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1505 - mean_absolute_error: 0.3019 - acc: 0.8197 - val_loss: 0.0387 - val_mean_absolute_error: 0.1739 - val_acc: 0.9905
# Epoch 27/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1516 - mean_absolute_error: 0.3023 - acc: 0.8159 - val_loss: 0.0500 - val_mean_absolute_error: 0.1868 - val_acc: 0.9611
# Epoch 28/1000
# 3422/3422 [==============================] - 8s 2ms/step - loss: 0.1531 - mean_absolute_error: 0.3002 - acc: 0.8182 - val_loss: 0.0111 - val_mean_absolute_error: 0.0520 - val_acc: 0.9911
# Epoch 29/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1469 - mean_absolute_error: 0.2950 - acc: 0.8282 - val_loss: 0.0487 - val_mean_absolute_error: 0.2021 - val_acc: 0.9843
# Epoch 30/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1491 - mean_absolute_error: 0.2970 - acc: 0.8226 - val_loss: 0.0355 - val_mean_absolute_error: 0.1016 - val_acc: 0.9611
# Epoch 31/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1480 - mean_absolute_error: 0.3003 - acc: 0.8174 - val_loss: 0.0133 - val_mean_absolute_error: 0.0658 - val_acc: 0.9884
# Epoch 32/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1443 - mean_absolute_error: 0.2965 - acc: 0.8314 - val_loss: 0.0148 - val_mean_absolute_error: 0.0932 - val_acc: 0.9939
# Epoch 33/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.1460 - mean_absolute_error: 0.2967 - acc: 0.8241 - val_loss: 0.0079 - val_mean_absolute_error: 0.0614 - val_acc: 0.9959
# Epoch 34/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1434 - mean_absolute_error: 0.2941 - acc: 0.8355 - val_loss: 0.0202 - val_mean_absolute_error: 0.1087 - val_acc: 0.9939
# Epoch 35/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1345 - mean_absolute_error: 0.2841 - acc: 0.8390 - val_loss: 0.0657 - val_mean_absolute_error: 0.2312 - val_acc: 0.9618
# Epoch 36/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1298 - mean_absolute_error: 0.2788 - acc: 0.8451 - val_loss: 0.0386 - val_mean_absolute_error: 0.1319 - val_acc: 0.9611
# Epoch 37/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1287 - mean_absolute_error: 0.2777 - acc: 0.8542 - val_loss: 0.0651 - val_mean_absolute_error: 0.2205 - val_acc: 0.9605
# Epoch 38/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1342 - mean_absolute_error: 0.2841 - acc: 0.8404 - val_loss: 0.0199 - val_mean_absolute_error: 0.1133 - val_acc: 0.9905
# Epoch 39/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1339 - mean_absolute_error: 0.2828 - acc: 0.8407 - val_loss: 0.0112 - val_mean_absolute_error: 0.0556 - val_acc: 0.9945
# Epoch 40/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1256 - mean_absolute_error: 0.2736 - acc: 0.8527 - val_loss: 0.0169 - val_mean_absolute_error: 0.1166 - val_acc: 0.9952
# Epoch 41/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1259 - mean_absolute_error: 0.2778 - acc: 0.8533 - val_loss: 0.0195 - val_mean_absolute_error: 0.1221 - val_acc: 0.9945
# Epoch 42/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.1231 - mean_absolute_error: 0.2698 - acc: 0.8594 - val_loss: 0.0045 - val_mean_absolute_error: 0.0331 - val_acc: 0.9973
# Epoch 43/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1222 - mean_absolute_error: 0.2706 - acc: 0.8591 - val_loss: 0.0175 - val_mean_absolute_error: 0.1113 - val_acc: 0.9945
# Epoch 44/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1232 - mean_absolute_error: 0.2725 - acc: 0.8568 - val_loss: 0.0088 - val_mean_absolute_error: 0.0332 - val_acc: 0.9932
# Epoch 45/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1173 - mean_absolute_error: 0.2666 - acc: 0.8720 - val_loss: 0.0363 - val_mean_absolute_error: 0.1709 - val_acc: 0.9986
# Epoch 46/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1185 - mean_absolute_error: 0.2667 - acc: 0.8600 - val_loss: 0.0105 - val_mean_absolute_error: 0.0871 - val_acc: 0.9945
# Epoch 47/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1153 - mean_absolute_error: 0.2618 - acc: 0.8697 - val_loss: 0.0271 - val_mean_absolute_error: 0.1441 - val_acc: 0.9932
# Epoch 48/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.1182 - mean_absolute_error: 0.2652 - acc: 0.8647 - val_loss: 0.0072 - val_mean_absolute_error: 0.0373 - val_acc: 0.9925
# Epoch 49/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.1087 - mean_absolute_error: 0.2558 - acc: 0.8831 - val_loss: 0.0243 - val_mean_absolute_error: 0.1203 - val_acc: 0.9877
# Epoch 50/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.1054 - mean_absolute_error: 0.2503 - acc: 0.8837 - val_loss: 0.0051 - val_mean_absolute_error: 0.0428 - val_acc: 0.9959
# Epoch 51/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.1056 - mean_absolute_error: 0.2498 - acc: 0.8928 - val_loss: 0.0085 - val_mean_absolute_error: 0.0623 - val_acc: 0.9959
# Epoch 52/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.1102 - mean_absolute_error: 0.2551 - acc: 0.8854 - val_loss: 0.0118 - val_mean_absolute_error: 0.0552 - val_acc: 0.9884
# Epoch 53/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.1041 - mean_absolute_error: 0.2478 - acc: 0.8898 - val_loss: 0.0082 - val_mean_absolute_error: 0.0727 - val_acc: 0.9966
# Epoch 54/1000
# 3422/3422 [==============================] - 12s 4ms/step - loss: 0.1002 - mean_absolute_error: 0.2445 - acc: 0.8901 - val_loss: 0.0145 - val_mean_absolute_error: 0.0989 - val_acc: 0.9932
# Epoch 55/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1050 - mean_absolute_error: 0.2476 - acc: 0.8831 - val_loss: 0.0064 - val_mean_absolute_error: 0.0506 - val_acc: 0.9986
# Epoch 56/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0983 - mean_absolute_error: 0.2408 - acc: 0.8895 - val_loss: 0.0346 - val_mean_absolute_error: 0.1734 - val_acc: 0.9966
# Epoch 57/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.1035 - mean_absolute_error: 0.2479 - acc: 0.8910 - val_loss: 0.0085 - val_mean_absolute_error: 0.0708 - val_acc: 0.9945
# Epoch 58/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0937 - mean_absolute_error: 0.2357 - acc: 0.9044 - val_loss: 0.0198 - val_mean_absolute_error: 0.0686 - val_acc: 0.9836
# Epoch 59/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.1027 - mean_absolute_error: 0.2479 - acc: 0.8904 - val_loss: 0.0193 - val_mean_absolute_error: 0.0853 - val_acc: 0.9850
# Epoch 60/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0926 - mean_absolute_error: 0.2368 - acc: 0.9044 - val_loss: 0.0092 - val_mean_absolute_error: 0.0616 - val_acc: 0.9959
# Epoch 61/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0964 - mean_absolute_error: 0.2384 - acc: 0.9039 - val_loss: 0.0054 - val_mean_absolute_error: 0.0381 - val_acc: 0.9945
# Epoch 62/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0929 - mean_absolute_error: 0.2360 - acc: 0.9044 - val_loss: 0.0590 - val_mean_absolute_error: 0.2203 - val_acc: 0.9993
# Epoch 63/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0856 - mean_absolute_error: 0.2268 - acc: 0.9161 - val_loss: 0.0195 - val_mean_absolute_error: 0.1052 - val_acc: 0.9918
# Epoch 64/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0905 - mean_absolute_error: 0.2308 - acc: 0.9044 - val_loss: 0.0056 - val_mean_absolute_error: 0.0431 - val_acc: 0.9945
# Epoch 65/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0914 - mean_absolute_error: 0.2319 - acc: 0.9106 - val_loss: 0.0036 - val_mean_absolute_error: 0.0422 - val_acc: 0.9986
# Epoch 66/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0867 - mean_absolute_error: 0.2244 - acc: 0.9176 - val_loss: 0.0034 - val_mean_absolute_error: 0.0373 - val_acc: 0.9980
# Epoch 67/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0885 - mean_absolute_error: 0.2267 - acc: 0.9205 - val_loss: 0.0053 - val_mean_absolute_error: 0.0351 - val_acc: 0.9966
# Epoch 68/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0886 - mean_absolute_error: 0.2295 - acc: 0.9059 - val_loss: 0.0421 - val_mean_absolute_error: 0.1604 - val_acc: 0.9959
# Epoch 69/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0885 - mean_absolute_error: 0.2302 - acc: 0.9117 - val_loss: 0.0226 - val_mean_absolute_error: 0.1196 - val_acc: 0.9864
# Epoch 70/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0875 - mean_absolute_error: 0.2296 - acc: 0.9161 - val_loss: 0.0127 - val_mean_absolute_error: 0.0834 - val_acc: 0.9959
# Epoch 71/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0799 - mean_absolute_error: 0.2189 - acc: 0.9252 - val_loss: 0.0129 - val_mean_absolute_error: 0.0740 - val_acc: 0.9966
# Epoch 72/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0827 - mean_absolute_error: 0.2232 - acc: 0.9191 - val_loss: 0.0079 - val_mean_absolute_error: 0.0624 - val_acc: 0.9980
# Epoch 73/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0851 - mean_absolute_error: 0.2231 - acc: 0.9202 - val_loss: 0.0025 - val_mean_absolute_error: 0.0365 - val_acc: 0.9993
# Epoch 74/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0824 - mean_absolute_error: 0.2229 - acc: 0.9234 - val_loss: 0.0026 - val_mean_absolute_error: 0.0196 - val_acc: 0.9986
# Epoch 75/1000
# 3422/3422 [==============================] - 12s 4ms/step - loss: 0.0833 - mean_absolute_error: 0.2242 - acc: 0.9144 - val_loss: 0.0193 - val_mean_absolute_error: 0.0984 - val_acc: 0.9905
# Epoch 76/1000
# 3422/3422 [==============================] - 13s 4ms/step - loss: 0.0858 - mean_absolute_error: 0.2249 - acc: 0.9150 - val_loss: 0.0084 - val_mean_absolute_error: 0.0516 - val_acc: 0.9959
# Epoch 77/1000
# 3422/3422 [==============================] - 13s 4ms/step - loss: 0.0829 - mean_absolute_error: 0.2235 - acc: 0.9223 - val_loss: 0.0072 - val_mean_absolute_error: 0.0544 - val_acc: 0.9952
# Epoch 78/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0825 - mean_absolute_error: 0.2206 - acc: 0.9196 - val_loss: 0.0054 - val_mean_absolute_error: 0.0564 - val_acc: 0.9980
# Epoch 79/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0770 - mean_absolute_error: 0.2143 - acc: 0.9299 - val_loss: 0.0042 - val_mean_absolute_error: 0.0369 - val_acc: 0.9966
# Epoch 80/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0770 - mean_absolute_error: 0.2126 - acc: 0.9325 - val_loss: 0.0046 - val_mean_absolute_error: 0.0447 - val_acc: 0.9993
# Epoch 81/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0756 - mean_absolute_error: 0.2124 - acc: 0.9319 - val_loss: 0.0145 - val_mean_absolute_error: 0.0569 - val_acc: 0.9932
# Epoch 82/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0759 - mean_absolute_error: 0.2115 - acc: 0.9340 - val_loss: 0.0089 - val_mean_absolute_error: 0.0595 - val_acc: 0.9918
# Epoch 83/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0762 - mean_absolute_error: 0.2141 - acc: 0.9299 - val_loss: 0.0139 - val_mean_absolute_error: 0.0729 - val_acc: 0.9864
# Epoch 84/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0749 - mean_absolute_error: 0.2100 - acc: 0.9325 - val_loss: 0.0028 - val_mean_absolute_error: 0.0237 - val_acc: 0.9980
# Epoch 85/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0734 - mean_absolute_error: 0.2107 - acc: 0.9395 - val_loss: 0.0113 - val_mean_absolute_error: 0.0534 - val_acc: 0.9864
# Epoch 86/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0758 - mean_absolute_error: 0.2144 - acc: 0.9305 - val_loss: 0.0059 - val_mean_absolute_error: 0.0378 - val_acc: 0.9959
# Epoch 87/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0728 - mean_absolute_error: 0.2076 - acc: 0.9337 - val_loss: 0.0310 - val_mean_absolute_error: 0.1250 - val_acc: 0.9932
# Epoch 88/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0721 - mean_absolute_error: 0.2090 - acc: 0.9363 - val_loss: 0.0035 - val_mean_absolute_error: 0.0235 - val_acc: 0.9973
# Epoch 89/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0745 - mean_absolute_error: 0.2066 - acc: 0.9389 - val_loss: 0.0037 - val_mean_absolute_error: 0.0372 - val_acc: 0.9993
# Epoch 90/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0731 - mean_absolute_error: 0.2090 - acc: 0.9366 - val_loss: 0.0055 - val_mean_absolute_error: 0.0382 - val_acc: 0.9959
# Epoch 91/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0710 - mean_absolute_error: 0.2063 - acc: 0.9451 - val_loss: 0.0059 - val_mean_absolute_error: 0.0439 - val_acc: 0.9959
# Epoch 92/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0702 - mean_absolute_error: 0.2038 - acc: 0.9451 - val_loss: 0.0110 - val_mean_absolute_error: 0.0666 - val_acc: 0.9939
# Epoch 93/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0684 - mean_absolute_error: 0.2026 - acc: 0.9421 - val_loss: 0.0081 - val_mean_absolute_error: 0.0610 - val_acc: 0.9980
# Epoch 94/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0710 - mean_absolute_error: 0.2053 - acc: 0.9448 - val_loss: 0.0056 - val_mean_absolute_error: 0.0463 - val_acc: 0.9966
# Epoch 95/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0696 - mean_absolute_error: 0.2032 - acc: 0.9421 - val_loss: 0.0045 - val_mean_absolute_error: 0.0565 - val_acc: 0.9986
# Epoch 96/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0676 - mean_absolute_error: 0.1990 - acc: 0.9427 - val_loss: 0.0089 - val_mean_absolute_error: 0.0638 - val_acc: 0.9966
# Epoch 97/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0651 - mean_absolute_error: 0.1973 - acc: 0.9471 - val_loss: 0.0125 - val_mean_absolute_error: 0.0820 - val_acc: 0.9939
# Epoch 98/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0654 - mean_absolute_error: 0.1987 - acc: 0.9500 - val_loss: 0.0031 - val_mean_absolute_error: 0.0431 - val_acc: 0.9993
# Epoch 99/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0661 - mean_absolute_error: 0.1984 - acc: 0.9553 - val_loss: 0.0045 - val_mean_absolute_error: 0.0471 - val_acc: 0.9980
# Epoch 100/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0657 - mean_absolute_error: 0.1951 - acc: 0.9462 - val_loss: 0.0127 - val_mean_absolute_error: 0.0945 - val_acc: 0.998046 - mean_ab - ETA: 1s - loss: 0.0664 - mean_absolute_error: 0.1963
# Epoch 101/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0644 - mean_absolute_error: 0.1930 - acc: 0.9527 - val_loss: 0.0040 - val_mean_absolute_error: 0.0251 - val_acc: 0.9959
# Epoch 102/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0648 - mean_absolute_error: 0.1981 - acc: 0.9503 - val_loss: 0.0272 - val_mean_absolute_error: 0.1124 - val_acc: 0.9816
# Epoch 103/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0647 - mean_absolute_error: 0.1955 - acc: 0.9512 - val_loss: 0.0112 - val_mean_absolute_error: 0.0488 - val_acc: 0.9959
# Epoch 104/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0629 - mean_absolute_error: 0.1944 - acc: 0.9544 - val_loss: 0.0155 - val_mean_absolute_error: 0.0648 - val_acc: 0.9884
# Epoch 105/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0618 - mean_absolute_error: 0.1925 - acc: 0.9570 - val_loss: 0.0018 - val_mean_absolute_error: 0.0195 - val_acc: 0.9993
# Epoch 106/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0615 - mean_absolute_error: 0.1932 - acc: 0.9588 - val_loss: 0.0118 - val_mean_absolute_error: 0.0660 - val_acc: 0.99730.0599 - mean_absolute_error: 0.1914 -  - ETA: 1s - loss: 0.0607 - mean_absolute_error: 0.19
# Epoch 107/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0616 - mean_absolute_error: 0.1909 - acc: 0.9547 - val_loss: 0.0026 - val_mean_absolute_error: 0.0171 - val_acc: 0.9980
# Epoch 108/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0632 - mean_absolute_error: 0.1919 - acc: 0.9524 - val_loss: 0.0064 - val_mean_absolute_error: 0.0662 - val_acc: 0.9980
# Epoch 109/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0599 - mean_absolute_error: 0.1893 - acc: 0.9611 - val_loss: 0.0092 - val_mean_absolute_error: 0.0517 - val_acc: 0.9945
# Epoch 110/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0598 - mean_absolute_error: 0.1884 - acc: 0.9600 - val_loss: 0.0034 - val_mean_absolute_error: 0.0216 - val_acc: 0.9966
# Epoch 111/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0596 - mean_absolute_error: 0.1884 - acc: 0.9620 - val_loss: 0.0064 - val_mean_absolute_error: 0.0383 - val_acc: 0.9959
# Epoch 112/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0630 - mean_absolute_error: 0.1892 - acc: 0.9535 - val_loss: 0.0020 - val_mean_absolute_error: 0.0217 - val_acc: 0.9986
# Epoch 113/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0600 - mean_absolute_error: 0.1888 - acc: 0.9550 - val_loss: 0.0045 - val_mean_absolute_error: 0.0472 - val_acc: 0.9980
# Epoch 114/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0581 - mean_absolute_error: 0.1850 - acc: 0.9605 - val_loss: 0.0047 - val_mean_absolute_error: 0.0445 - val_acc: 0.9980
# Epoch 115/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0611 - mean_absolute_error: 0.1895 - acc: 0.9553 - val_loss: 0.0050 - val_mean_absolute_error: 0.0497 - val_acc: 0.9980
# Epoch 116/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0589 - mean_absolute_error: 0.1868 - acc: 0.9611 - val_loss: 0.0035 - val_mean_absolute_error: 0.0345 - val_acc: 0.9980error: 0.1840 -
# Epoch 117/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0575 - mean_absolute_error: 0.1840 - acc: 0.9605 - val_loss: 0.0047 - val_mean_absolute_error: 0.0493 - val_acc: 0.9980
# Epoch 118/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0572 - mean_absolute_error: 0.1832 - acc: 0.9585 - val_loss: 0.0041 - val_mean_absolute_error: 0.0378 - val_acc: 0.9986
# Epoch 119/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0539 - mean_absolute_error: 0.1789 - acc: 0.9626 - val_loss: 0.0018 - val_mean_absolute_error: 0.0250 - val_acc: 0.9986
# Epoch 120/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0590 - mean_absolute_error: 0.1879 - acc: 0.9588 - val_loss: 0.0050 - val_mean_absolute_error: 0.0448 - val_acc: 0.9973
# Epoch 121/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0518 - mean_absolute_error: 0.1762 - acc: 0.9670 - val_loss: 0.0056 - val_mean_absolute_error: 0.0487 - val_acc: 0.9973
# Epoch 122/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0564 - mean_absolute_error: 0.1819 - acc: 0.9667 - val_loss: 0.0060 - val_mean_absolute_error: 0.0476 - val_acc: 0.9959
# Epoch 123/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1777 - acc: 0.9641 - val_loss: 0.0021 - val_mean_absolute_error: 0.0352 - val_acc: 0.9993
# Epoch 124/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0530 - mean_absolute_error: 0.1749 - acc: 0.9667 - val_loss: 0.0098 - val_mean_absolute_error: 0.0604 - val_acc: 0.9966
# Epoch 125/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1778 - acc: 0.9643 - val_loss: 0.0032 - val_mean_absolute_error: 0.0375 - val_acc: 0.9986
# Epoch 126/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0517 - mean_absolute_error: 0.1760 - acc: 0.9702 - val_loss: 0.0037 - val_mean_absolute_error: 0.0390 - val_acc: 0.9986
# Epoch 127/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0532 - mean_absolute_error: 0.1747 - acc: 0.9679 - val_loss: 0.0059 - val_mean_absolute_error: 0.0514 - val_acc: 0.9966
# Epoch 128/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0529 - mean_absolute_error: 0.1765 - acc: 0.9646 - val_loss: 0.0020 - val_mean_absolute_error: 0.0275 - val_acc: 0.9986
# Epoch 129/1000
# 3422/3422 [==============================] - 13s 4ms/step - loss: 0.0518 - mean_absolute_error: 0.1740 - acc: 0.9699 - val_loss: 0.0049 - val_mean_absolute_error: 0.0567 - val_acc: 0.9980
# Epoch 130/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0514 - mean_absolute_error: 0.1732 - acc: 0.9702 - val_loss: 0.0023 - val_mean_absolute_error: 0.0347 - val_acc: 0.9986
# Epoch 131/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0533 - mean_absolute_error: 0.1757 - acc: 0.9661 - val_loss: 0.0085 - val_mean_absolute_error: 0.0577 - val_acc: 0.9993
# Epoch 132/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0506 - mean_absolute_error: 0.1737 - acc: 0.9719 - val_loss: 0.0048 - val_mean_absolute_error: 0.0508 - val_acc: 0.9993
# Epoch 133/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1689 - acc: 0.9699 - val_loss: 0.0097 - val_mean_absolute_error: 0.0610 - val_acc: 0.9952
# Epoch 134/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0538 - mean_absolute_error: 0.1776 - acc: 0.9652 - val_loss: 0.0040 - val_mean_absolute_error: 0.0453 - val_acc: 0.9993
# Epoch 135/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1708 - acc: 0.9714 - val_loss: 0.0042 - val_mean_absolute_error: 0.0388 - val_acc: 0.9966
# Epoch 136/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0513 - mean_absolute_error: 0.1719 - acc: 0.9681 - val_loss: 0.0220 - val_mean_absolute_error: 0.1102 - val_acc: 0.9986
# Epoch 137/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0505 - mean_absolute_error: 0.1712 - acc: 0.9646 - val_loss: 0.0041 - val_mean_absolute_error: 0.0444 - val_acc: 0.9986
# Epoch 138/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0522 - mean_absolute_error: 0.1715 - acc: 0.9676 - val_loss: 0.0015 - val_mean_absolute_error: 0.0261 - val_acc: 0.9993
# Epoch 139/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0489 - mean_absolute_error: 0.1688 - acc: 0.9708 - val_loss: 0.0054 - val_mean_absolute_error: 0.0463 - val_acc: 0.9973.0486 - mean_absolute_error: 0.1685 - ac
# Epoch 140/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0483 - mean_absolute_error: 0.1695 - acc: 0.9737 - val_loss: 0.0132 - val_mean_absolute_error: 0.0839 - val_acc: 0.9993
# Epoch 141/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1647 - acc: 0.9731 - val_loss: 0.0085 - val_mean_absolute_error: 0.0563 - val_acc: 0.9932
# Epoch 142/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1638 - acc: 0.9734 - val_loss: 0.0028 - val_mean_absolute_error: 0.0314 - val_acc: 0.9980
# Epoch 143/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0467 - mean_absolute_error: 0.1635 - acc: 0.9734 - val_loss: 0.0092 - val_mean_absolute_error: 0.0763 - val_acc: 0.9980
# Epoch 144/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1663 - acc: 0.9711 - val_loss: 0.0030 - val_mean_absolute_error: 0.0332 - val_acc: 0.9980
# Epoch 145/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0449 - mean_absolute_error: 0.1623 - acc: 0.9731 - val_loss: 0.0034 - val_mean_absolute_error: 0.0428 - val_acc: 0.9986
# Epoch 146/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0464 - mean_absolute_error: 0.1608 - acc: 0.9752 - val_loss: 0.0068 - val_mean_absolute_error: 0.0527 - val_acc: 0.9973
# Epoch 147/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0453 - mean_absolute_error: 0.1606 - acc: 0.9775 - val_loss: 0.0034 - val_mean_absolute_error: 0.0363 - val_acc: 0.9966
# Epoch 148/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0430 - mean_absolute_error: 0.1586 - acc: 0.9757 - val_loss: 0.0028 - val_mean_absolute_error: 0.0395 - val_acc: 0.9986rror: 0.1590 - acc - ETA: 0s - loss: 0.0431 - mean_absolute_error: 0.1585 - acc:
# Epoch 149/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0444 - mean_absolute_error: 0.1597 - acc: 0.9757 - val_loss: 0.0068 - val_mean_absolute_error: 0.0496 - val_acc: 0.9959
# Epoch 150/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0420 - mean_absolute_error: 0.1565 - acc: 0.9763 - val_loss: 0.0018 - val_mean_absolute_error: 0.0271 - val_acc: 0.9993
# Epoch 151/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.1600 - acc: 0.9760 - val_loss: 0.0074 - val_mean_absolute_error: 0.0530 - val_acc: 0.9952
# Epoch 152/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0410 - mean_absolute_error: 0.1578 - acc: 0.9793 - val_loss: 0.0040 - val_mean_absolute_error: 0.0296 - val_acc: 0.9973
# Epoch 153/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1580 - acc: 0.9760 - val_loss: 0.0020 - val_mean_absolute_error: 0.0225 - val_acc: 0.9993
# Epoch 154/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0417 - mean_absolute_error: 0.1556 - acc: 0.9781 - val_loss: 0.0057 - val_mean_absolute_error: 0.0532 - val_acc: 0.9966
# Epoch 155/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1586 - acc: 0.9795 - val_loss: 0.0047 - val_mean_absolute_error: 0.0285 - val_acc: 0.9945
# Epoch 156/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0436 - mean_absolute_error: 0.1545 - acc: 0.9778 - val_loss: 0.0024 - val_mean_absolute_error: 0.0261 - val_acc: 0.9986
# Epoch 157/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0450 - mean_absolute_error: 0.1586 - acc: 0.9728 - val_loss: 0.0028 - val_mean_absolute_error: 0.0296 - val_acc: 0.9980
# Epoch 158/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0392 - mean_absolute_error: 0.1503 - acc: 0.9825 - val_loss: 0.0071 - val_mean_absolute_error: 0.0370 - val_acc: 0.9945
# Epoch 159/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0418 - mean_absolute_error: 0.1553 - acc: 0.9790 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333 - val_acc: 0.9986
# Epoch 160/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0418 - mean_absolute_error: 0.1554 - acc: 0.9766 - val_loss: 0.0070 - val_mean_absolute_error: 0.0507 - val_acc: 0.9986
# Epoch 161/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1500 - acc: 0.9828 - val_loss: 0.0015 - val_mean_absolute_error: 0.0185 - val_acc: 0.9993
# Epoch 162/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0413 - mean_absolute_error: 0.1500 - acc: 0.9825 - val_loss: 0.0091 - val_mean_absolute_error: 0.0505 - val_acc: 0.9959
# Epoch 163/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0397 - mean_absolute_error: 0.1502 - acc: 0.9828 - val_loss: 0.0059 - val_mean_absolute_error: 0.0483 - val_acc: 0.9973
# Epoch 164/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0394 - mean_absolute_error: 0.1488 - acc: 0.9787 - val_loss: 0.0088 - val_mean_absolute_error: 0.0822 - val_acc: 0.9993
# Epoch 165/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1464 - acc: 0.9839 - val_loss: 0.0032 - val_mean_absolute_error: 0.0262 - val_acc: 0.9966
# Epoch 166/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0358 - mean_absolute_error: 0.1442 - acc: 0.9848 - val_loss: 0.0021 - val_mean_absolute_error: 0.0150 - val_acc: 0.9986
# Epoch 167/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0393 - mean_absolute_error: 0.1482 - acc: 0.9822 - val_loss: 0.0032 - val_mean_absolute_error: 0.0334 - val_acc: 0.9980
# Epoch 168/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1472 - acc: 0.9819 - val_loss: 0.0043 - val_mean_absolute_error: 0.0419 - val_acc: 0.9980
# Epoch 169/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1439 - acc: 0.9807 - val_loss: 0.0024 - val_mean_absolute_error: 0.0252 - val_acc: 0.9986
# Epoch 170/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0369 - mean_absolute_error: 0.1449 - acc: 0.9819 - val_loss: 0.0028 - val_mean_absolute_error: 0.0221 - val_acc: 0.9980
# Epoch 171/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0370 - mean_absolute_error: 0.1451 - acc: 0.9822 - val_loss: 0.0033 - val_mean_absolute_error: 0.0240 - val_acc: 0.9980
# Epoch 172/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1427 - acc: 0.9828 - val_loss: 0.0020 - val_mean_absolute_error: 0.0198 - val_acc: 0.9986
# Epoch 173/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0362 - mean_absolute_error: 0.1434 - acc: 0.9828 - val_loss: 0.0024 - val_mean_absolute_error: 0.0344 - val_acc: 0.9986
# Epoch 174/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1414 - acc: 0.9871 - val_loss: 0.0051 - val_mean_absolute_error: 0.0396 - val_acc: 0.996616 - mean_absolute_error: 0.1378 -  - ETA: 4s - loss:
# Epoch 175/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1436 - acc: 0.9836 - val_loss: 0.0028 - val_mean_absolute_error: 0.0278 - val_acc: 0.9986
# Epoch 176/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.1416 - acc: 0.9825 - val_loss: 0.0027 - val_mean_absolute_error: 0.0174 - val_acc: 0.9973
# Epoch 177/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0352 - mean_absolute_error: 0.1415 - acc: 0.9839 - val_loss: 0.0068 - val_mean_absolute_error: 0.0404 - val_acc: 0.9966
# Epoch 178/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0341 - mean_absolute_error: 0.1380 - acc: 0.9851 - val_loss: 0.0039 - val_mean_absolute_error: 0.0342 - val_acc: 0.9986s - loss: 0.0352 - m
# Epoch 179/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.1398 - acc: 0.9848 - val_loss: 0.0026 - val_mean_absolute_error: 0.0417 - val_acc: 0.9986
# Epoch 180/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0331 - mean_absolute_error: 0.1375 - acc: 0.9863 - val_loss: 0.0094 - val_mean_absolute_error: 0.0466 - val_acc: 0.9932
# Epoch 181/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.1406 - acc: 0.9836 - val_loss: 0.0055 - val_mean_absolute_error: 0.0281 - val_acc: 0.9973
# Epoch 182/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0360 - mean_absolute_error: 0.1413 - acc: 0.9839 - val_loss: 0.0029 - val_mean_absolute_error: 0.0181 - val_acc: 0.9973
# Epoch 183/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0329 - mean_absolute_error: 0.1378 - acc: 0.9863 - val_loss: 0.0014 - val_mean_absolute_error: 0.0174 - val_acc: 0.9986.986
# Epoch 184/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0329 - mean_absolute_error: 0.1340 - acc: 0.9860 - val_loss: 0.0036 - val_mean_absolute_error: 0.0257 - val_acc: 0.9973
# Epoch 185/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1326 - acc: 0.9892 - val_loss: 0.0037 - val_mean_absolute_error: 0.0346 - val_acc: 0.9973
# Epoch 186/1000
# 3422/3422 [==============================] - 12s 4ms/step - loss: 0.0329 - mean_absolute_error: 0.1351 - acc: 0.9851 - val_loss: 0.0040 - val_mean_absolute_error: 0.0302 - val_acc: 0.9959
# Epoch 187/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0313 - mean_absolute_error: 0.1327 - acc: 0.9868 - val_loss: 0.0034 - val_mean_absolute_error: 0.0431 - val_acc: 0.9986
# Epoch 188/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1319 - acc: 0.9851 - val_loss: 0.0070 - val_mean_absolute_error: 0.0566 - val_acc: 0.9993 - mean_absolute_error: 0.1358 - acc: - ETA: 4s - loss: 0.0332
# Epoch 189/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0310 - mean_absolute_error: 0.1313 - acc: 0.9871 - val_loss: 0.0123 - val_mean_absolute_error: 0.0931 - val_acc: 0.9980e - ETA: 1s - loss: 0.0305 - mean_absolute_error: 0.130
# Epoch 190/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0294 - mean_absolute_error: 0.1297 - acc: 0.9901 - val_loss: 0.0027 - val_mean_absolute_error: 0.0418 - val_acc: 0.9993
# Epoch 191/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1281 - acc: 0.9857 - val_loss: 0.0033 - val_mean_absolute_error: 0.0453 - val_acc: 0.9986
# Epoch 192/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1314 - acc: 0.9828 - val_loss: 0.0027 - val_mean_absolute_error: 0.0226 - val_acc: 0.9986
# Epoch 193/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0294 - mean_absolute_error: 0.1247 - acc: 0.9883 - val_loss: 0.0031 - val_mean_absolute_error: 0.0330 - val_acc: 0.9986
# Epoch 194/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0311 - mean_absolute_error: 0.1296 - acc: 0.9848 - val_loss: 0.0033 - val_mean_absolute_error: 0.0292 - val_acc: 0.9986
# Epoch 195/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0303 - mean_absolute_error: 0.1242 - acc: 0.9868 - val_loss: 0.0164 - val_mean_absolute_error: 0.0983 - val_acc: 0.9911
# Epoch 196/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0319 - mean_absolute_error: 0.1278 - acc: 0.9871 - val_loss: 0.0037 - val_mean_absolute_error: 0.0502 - val_acc: 0.9986
# Epoch 197/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1267 - acc: 0.9880 - val_loss: 0.0027 - val_mean_absolute_error: 0.0271 - val_acc: 0.9973
# Epoch 198/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.1251 - acc: 0.9860 - val_loss: 0.0069 - val_mean_absolute_error: 0.0543 - val_acc: 0.9973
# Epoch 199/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0285 - mean_absolute_error: 0.1266 - acc: 0.9892 - val_loss: 0.0040 - val_mean_absolute_error: 0.0507 - val_acc: 0.9980
# Epoch 200/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1256 - acc: 0.9836 - val_loss: 0.0057 - val_mean_absolute_error: 0.0485 - val_acc: 0.9980
# Epoch 201/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0283 - mean_absolute_error: 0.1228 - acc: 0.9866 - val_loss: 0.0030 - val_mean_absolute_error: 0.0264 - val_acc: 0.9986
# Epoch 202/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0270 - mean_absolute_error: 0.1198 - acc: 0.9904 - val_loss: 0.0069 - val_mean_absolute_error: 0.0451 - val_acc: 0.9952
# Epoch 203/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0278 - mean_absolute_error: 0.1202 - acc: 0.9886 - val_loss: 0.0031 - val_mean_absolute_error: 0.0275 - val_acc: 0.9973
# Epoch 204/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0284 - mean_absolute_error: 0.1228 - acc: 0.9871 - val_loss: 0.0013 - val_mean_absolute_error: 0.0133 - val_acc: 0.9993
# Epoch 205/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0266 - mean_absolute_error: 0.1223 - acc: 0.9906 - val_loss: 0.0097 - val_mean_absolute_error: 0.0263 - val_acc: 0.9898
# Epoch 206/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0280 - mean_absolute_error: 0.1218 - acc: 0.9880 - val_loss: 0.0042 - val_mean_absolute_error: 0.0339 - val_acc: 0.99861218 - acc:
# Epoch 207/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0286 - mean_absolute_error: 0.1214 - acc: 0.9901 - val_loss: 0.0053 - val_mean_absolute_error: 0.0376 - val_acc: 0.9973
# Epoch 208/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1222 - acc: 0.9880 - val_loss: 0.0011 - val_mean_absolute_error: 0.0108 - val_acc: 0.9993.0300 - mean_absolute_error: 0.1222 - ac
# Epoch 209/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0262 - mean_absolute_error: 0.1187 - acc: 0.9898 - val_loss: 0.0021 - val_mean_absolute_error: 0.0179 - val_acc: 0.9980- loss: 0.0262 - mean_absolute_error: 0.1186 -
# Epoch 210/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0267 - mean_absolute_error: 0.1188 - acc: 0.9895 - val_loss: 0.0018 - val_mean_absolute_error: 0.0245 - val_acc: 0.9986
# Epoch 211/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0264 - mean_absolute_error: 0.1173 - acc: 0.9892 - val_loss: 0.0073 - val_mean_absolute_error: 0.0706 - val_acc: 0.9973
# Epoch 212/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.1171 - acc: 0.9895 - val_loss: 0.0055 - val_mean_absolute_error: 0.0363 - val_acc: 0.9966
# Epoch 213/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0260 - mean_absolute_error: 0.1174 - acc: 0.9886 - val_loss: 0.0014 - val_mean_absolute_error: 0.0114 - val_acc: 0.9986
# Epoch 214/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.1165 - acc: 0.9892 - val_loss: 0.0034 - val_mean_absolute_error: 0.0233 - val_acc: 0.9966ss: 0.0264 - mean_absolute_error: 0.1166 - acc:
# Epoch 215/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0255 - mean_absolute_error: 0.1148 - acc: 0.9886 - val_loss: 0.0040 - val_mean_absolute_error: 0.0229 - val_acc: 0.9966an_absolute_error: 0.1149 - acc:  - ETA: 0s - loss: 0.0253 - mean_absolute_error: 0.1149 - acc: 0.
# Epoch 216/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0268 - mean_absolute_error: 0.1155 - acc: 0.9880 - val_loss: 0.0028 - val_mean_absolute_error: 0.0270 - val_acc: 0.9973
# Epoch 217/1000
# 3422/3422 [==============================] - 12s 3ms/step - loss: 0.0248 - mean_absolute_error: 0.1155 - acc: 0.9915 - val_loss: 0.0023 - val_mean_absolute_error: 0.0186 - val_acc: 0.9973
# Epoch 218/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0261 - mean_absolute_error: 0.1152 - acc: 0.9889 - val_loss: 0.0027 - val_mean_absolute_error: 0.0270 - val_acc: 0.9986
# Epoch 219/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0262 - mean_absolute_error: 0.1161 - acc: 0.9898 - val_loss: 0.0035 - val_mean_absolute_error: 0.0295 - val_acc: 0.9973
# Epoch 220/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.1117 - acc: 0.9912 - val_loss: 0.0030 - val_mean_absolute_error: 0.0367 - val_acc: 0.9980
# Epoch 221/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1133 - acc: 0.9901 - val_loss: 0.0011 - val_mean_absolute_error: 0.0166 - val_acc: 0.9993
# Epoch 222/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0240 - mean_absolute_error: 0.1107 - acc: 0.9909 - val_loss: 0.0033 - val_mean_absolute_error: 0.0232 - val_acc: 0.9993
# Epoch 223/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.1083 - acc: 0.9895 - val_loss: 9.0184e-04 - val_mean_absolute_error: 0.0131 - val_acc: 0.9993
# Epoch 224/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0232 - mean_absolute_error: 0.1105 - acc: 0.9898 - val_loss: 0.0032 - val_mean_absolute_error: 0.0293 - val_acc: 0.9980
# Epoch 225/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0238 - mean_absolute_error: 0.1086 - acc: 0.9912 - val_loss: 0.0130 - val_mean_absolute_error: 0.0781 - val_acc: 0.9925
# Epoch 226/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0228 - mean_absolute_error: 0.1068 - acc: 0.9904 - val_loss: 0.0054 - val_mean_absolute_error: 0.0419 - val_acc: 0.9973
# Epoch 227/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1091 - acc: 0.9886 - val_loss: 0.0084 - val_mean_absolute_error: 0.0453 - val_acc: 0.9973
# Epoch 228/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0247 - mean_absolute_error: 0.1113 - acc: 0.9880 - val_loss: 0.0043 - val_mean_absolute_error: 0.0174 - val_acc: 0.9959
# Epoch 229/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0252 - mean_absolute_error: 0.1091 - acc: 0.9880 - val_loss: 0.0046 - val_mean_absolute_error: 0.0389 - val_acc: 0.9980
# Epoch 230/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0230 - mean_absolute_error: 0.1091 - acc: 0.9901 - val_loss: 0.0022 - val_mean_absolute_error: 0.0251 - val_acc: 0.9986
# Epoch 231/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0227 - mean_absolute_error: 0.1062 - acc: 0.9898 - val_loss: 9.7845e-04 - val_mean_absolute_error: 0.0199 - val_acc: 0.9993
# Epoch 232/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0251 - mean_absolute_error: 0.1086 - acc: 0.9892 - val_loss: 0.0110 - val_mean_absolute_error: 0.0899 - val_acc: 0.9973
# Epoch 233/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.1013 - acc: 0.9924 - val_loss: 0.0035 - val_mean_absolute_error: 0.0358 - val_acc: 0.9973
# Epoch 234/1000
# ...
# Epoch 618/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0187 - mean_absolute_error: 0.0611 - acc: 0.9842 - val_loss: 0.0042 - val_mean_absolute_error: 0.0176 - val_acc: 0.9952
# Epoch 619/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0521 - acc: 0.9927 - val_loss: 0.0044 - val_mean_absolute_error: 0.0355 - val_acc: 0.9980
# Epoch 620/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0165 - mean_absolute_error: 0.0590 - acc: 0.9866 - val_loss: 0.0040 - val_mean_absolute_error: 0.0447 - val_acc: 0.9973
# Epoch 621/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0542 - acc: 0.9895 - val_loss: 0.0029 - val_mean_absolute_error: 0.0152 - val_acc: 0.9966- mean_absolute_e - ETA: 5s - loss: 0.013 - ETA: 1s - loss: 0.0120 - mean_absolute_error: 0.0528
# Epoch 622/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0531 - acc: 0.9915 - val_loss: 0.0051 - val_mean_absolute_error: 0.0208 - val_acc: 0.9952
# Epoch 623/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0539 - acc: 0.9904 - val_loss: 0.0067 - val_mean_absolute_error: 0.0281 - val_acc: 0.9945
# Epoch 624/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0500 - acc: 0.9947 - val_loss: 0.0019 - val_mean_absolute_error: 0.0199 - val_acc: 0.9986
# Epoch 625/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0540 - acc: 0.9909 - val_loss: 0.0035 - val_mean_absolute_error: 0.0126 - val_acc: 0.9966
# Epoch 626/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0554 - acc: 0.9898 - val_loss: 0.0033 - val_mean_absolute_error: 0.0102 - val_acc: 0.9966
# Epoch 627/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0509 - acc: 0.9924 - val_loss: 0.0038 - val_mean_absolute_error: 0.0204 - val_acc: 0.9966
# Epoch 628/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0545 - acc: 0.9906 - val_loss: 0.0043 - val_mean_absolute_error: 0.0095 - val_acc: 0.9959
# Epoch 629/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0565 - acc: 0.9895 - val_loss: 0.0039 - val_mean_absolute_error: 0.0189 - val_acc: 0.9959
# Epoch 630/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0545 - acc: 0.9895 - val_loss: 0.0034 - val_mean_absolute_error: 0.0190 - val_acc: 0.9973
# Epoch 631/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0111 - mean_absolute_error: 0.0517 - acc: 0.9909 - val_loss: 0.0066 - val_mean_absolute_error: 0.0382 - val_acc: 0.9939
# Epoch 632/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0534 - acc: 0.9915 - val_loss: 0.0055 - val_mean_absolute_error: 0.0402 - val_acc: 0.9980
# Epoch 633/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0186 - mean_absolute_error: 0.0611 - acc: 0.9833 - val_loss: 0.0018 - val_mean_absolute_error: 0.0071 - val_acc: 0.9980
# Epoch 634/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0543 - acc: 0.9909 - val_loss: 0.0038 - val_mean_absolute_error: 0.0256 - val_acc: 0.9973
# Epoch 635/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0166 - mean_absolute_error: 0.0571 - acc: 0.9863 - val_loss: 0.0013 - val_mean_absolute_error: 0.0119 - val_acc: 0.9993
# Epoch 636/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0196 - mean_absolute_error: 0.0591 - acc: 0.9871 - val_loss: 0.0050 - val_mean_absolute_error: 0.0154 - val_acc: 0.9952
# Epoch 637/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0177 - mean_absolute_error: 0.0593 - acc: 0.9848 - val_loss: 0.0055 - val_mean_absolute_error: 0.0288 - val_acc: 0.9952
# Epoch 638/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0205 - mean_absolute_error: 0.0607 - acc: 0.9836 - val_loss: 0.0049 - val_mean_absolute_error: 0.0114 - val_acc: 0.9952
# Epoch 639/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0602 - acc: 0.9863 - val_loss: 0.0112 - val_mean_absolute_error: 0.0257 - val_acc: 0.9898
# Epoch 640/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0214 - mean_absolute_error: 0.0626 - acc: 0.9828 - val_loss: 0.0049 - val_mean_absolute_error: 0.0182 - val_acc: 0.9952
# Epoch 641/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0544 - acc: 0.9904 - val_loss: 0.0046 - val_mean_absolute_error: 0.0146 - val_acc: 0.9959
# Epoch 642/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0167 - mean_absolute_error: 0.0576 - acc: 0.9860 - val_loss: 0.0097 - val_mean_absolute_error: 0.0299 - val_acc: 0.9911
# Epoch 643/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0565 - acc: 0.9871 - val_loss: 0.0067 - val_mean_absolute_error: 0.0294 - val_acc: 0.9939
# Epoch 644/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.0655 - acc: 0.9804 - val_loss: 0.0095 - val_mean_absolute_error: 0.0298 - val_acc: 0.9918
# Epoch 645/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0191 - mean_absolute_error: 0.0602 - acc: 0.9848 - val_loss: 0.0151 - val_mean_absolute_error: 0.0322 - val_acc: 0.9870
# Epoch 646/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0219 - mean_absolute_error: 0.0626 - acc: 0.9845 - val_loss: 0.0125 - val_mean_absolute_error: 0.0350 - val_acc: 0.9870
# Epoch 647/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0250 - mean_absolute_error: 0.0650 - acc: 0.9828 - val_loss: 0.0180 - val_mean_absolute_error: 0.0403 - val_acc: 0.9830
# Epoch 648/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0286 - mean_absolute_error: 0.0674 - acc: 0.9784 - val_loss: 0.0193 - val_mean_absolute_error: 0.0237 - val_acc: 0.9802
# Epoch 649/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0573 - acc: 0.9877 - val_loss: 0.0079 - val_mean_absolute_error: 0.0327 - val_acc: 0.9932
# Epoch 650/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0178 - mean_absolute_error: 0.0585 - acc: 0.9860 - val_loss: 0.0044 - val_mean_absolute_error: 0.0224 - val_acc: 0.9959
# Epoch 651/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0528 - acc: 0.9912 - val_loss: 0.0073 - val_mean_absolute_error: 0.0621 - val_acc: 0.9973
# Epoch 652/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0541 - acc: 0.9889 - val_loss: 0.0046 - val_mean_absolute_error: 0.0111 - val_acc: 0.9945
# Epoch 653/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0177 - mean_absolute_error: 0.0584 - acc: 0.9863 - val_loss: 0.0064 - val_mean_absolute_error: 0.0285 - val_acc: 0.9939- loss: 0.0177 - mean_absolute_error: 0.0581 - a
# Epoch 654/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0120 - mean_absolute_error: 0.0530 - acc: 0.9906 - val_loss: 0.0043 - val_mean_absolute_error: 0.0192 - val_acc: 0.9952 mean_absol - ETA: 3s - loss: 0.0106 -
# Epoch 655/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0532 - acc: 0.9906 - val_loss: 0.0056 - val_mean_absolute_error: 0.0171 - val_acc: 0.9939- loss: 0.0130 - mean_absolute_error: 0.0533 - acc: 0.990
# Epoch 656/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0513 - acc: 0.9921 - val_loss: 0.0050 - val_mean_absolute_error: 0.0177 - val_acc: 0.9952olute_error: 0.0512 - acc: 0.
# Epoch 657/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0540 - acc: 0.9909 - val_loss: 0.0054 - val_mean_absolute_error: 0.0399 - val_acc: 0.9973
# Epoch 658/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0549 - acc: 0.9906 - val_loss: 0.0035 - val_mean_absolute_error: 0.0215 - val_acc: 0.9966
# Epoch 659/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0533 - acc: 0.9906 - val_loss: 0.0036 - val_mean_absolute_error: 0.0266 - val_acc: 0.99730.0133 - mean_absol - ETA:
# Epoch 660/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0153 - mean_absolute_error: 0.0551 - acc: 0.9889 - val_loss: 0.0037 - val_mean_absolute_error: 0.0176 - val_acc: 0.9966
# Epoch 661/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0566 - acc: 0.9883 - val_loss: 0.0054 - val_mean_absolute_error: 0.0239 - val_acc: 0.9952
# Epoch 662/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0505 - acc: 0.9924 - val_loss: 0.0056 - val_mean_absolute_error: 0.0186 - val_acc: 0.9952
# Epoch 663/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0558 - acc: 0.9904 - val_loss: 0.0058 - val_mean_absolute_error: 0.0475 - val_acc: 0.9980
# Epoch 664/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0533 - acc: 0.9912 - val_loss: 0.0035 - val_mean_absolute_error: 0.0146 - val_acc: 0.9966
# Epoch 665/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0517 - acc: 0.9921 - val_loss: 0.0055 - val_mean_absolute_error: 0.0280 - val_acc: 0.9952
# Epoch 666/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0515 - acc: 0.9939 - val_loss: 0.0038 - val_mean_absolute_error: 0.0119 - val_acc: 0.9952
# Epoch 667/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0181 - mean_absolute_error: 0.0560 - acc: 0.9895 - val_loss: 0.0022 - val_mean_absolute_error: 0.0092 - val_acc: 0.9980
# Epoch 668/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0512 - acc: 0.9927 - val_loss: 0.0043 - val_mean_absolute_error: 0.0166 - val_acc: 0.9959
# Epoch 669/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0538 - acc: 0.9904 - val_loss: 0.0047 - val_mean_absolute_error: 0.0163 - val_acc: 0.9945
# Epoch 670/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0539 - acc: 0.9906 - val_loss: 0.0054 - val_mean_absolute_error: 0.0208 - val_acc: 0.9939
# Epoch 671/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0543 - acc: 0.9909 - val_loss: 0.0085 - val_mean_absolute_error: 0.0289 - val_acc: 0.9925
# Epoch 672/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.0623 - acc: 0.9848 - val_loss: 0.0038 - val_mean_absolute_error: 0.0192 - val_acc: 0.9952
# Epoch 673/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0177 - mean_absolute_error: 0.0543 - acc: 0.9904 - val_loss: 0.0036 - val_mean_absolute_error: 0.0139 - val_acc: 0.9966
# Epoch 674/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0574 - acc: 0.9877 - val_loss: 0.0042 - val_mean_absolute_error: 0.0196 - val_acc: 0.9959
# Epoch 675/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0184 - mean_absolute_error: 0.0600 - acc: 0.9868 - val_loss: 0.0064 - val_mean_absolute_error: 0.0393 - val_acc: 0.9945
# Epoch 676/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0537 - acc: 0.9901 - val_loss: 0.0068 - val_mean_absolute_error: 0.0300 - val_acc: 0.9932
# Epoch 677/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0174 - mean_absolute_error: 0.0579 - acc: 0.9871 - val_loss: 0.0070 - val_mean_absolute_error: 0.0326 - val_acc: 0.9939
# Epoch 678/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0544 - acc: 0.9898 - val_loss: 0.0030 - val_mean_absolute_error: 0.0147 - val_acc: 0.9973
# Epoch 679/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0556 - acc: 0.9877 - val_loss: 0.0077 - val_mean_absolute_error: 0.0232 - val_acc: 0.9918
# Epoch 680/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0173 - mean_absolute_error: 0.0586 - acc: 0.9863 - val_loss: 0.0067 - val_mean_absolute_error: 0.0284 - val_acc: 0.9939
# Epoch 681/1000
# 3422/3422 [==============================] - 11s 3ms/step - loss: 0.0197 - mean_absolute_error: 0.0569 - acc: 0.9898 - val_loss: 0.0044 - val_mean_absolute_error: 0.0189 - val_acc: 0.9959
# Epoch 682/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0511 - acc: 0.9915 - val_loss: 0.0089 - val_mean_absolute_error: 0.0329 - val_acc: 0.9939
# Epoch 683/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0555 - acc: 0.9895 - val_loss: 0.0089 - val_mean_absolute_error: 0.0244 - val_acc: 0.9925
# Epoch 684/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0504 - acc: 0.9933 - val_loss: 0.0052 - val_mean_absolute_error: 0.0202 - val_acc: 0.9952
# Epoch 685/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0522 - acc: 0.9918 - val_loss: 0.0080 - val_mean_absolute_error: 0.0436 - val_acc: 0.9952
# Epoch 686/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0556 - acc: 0.9880 - val_loss: 0.0040 - val_mean_absolute_error: 0.0242 - val_acc: 0.9959
# Epoch 687/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0514 - acc: 0.9936 - val_loss: 0.0023 - val_mean_absolute_error: 0.0177 - val_acc: 0.9973
# Epoch 688/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0173 - mean_absolute_error: 0.0546 - acc: 0.9877 - val_loss: 0.0033 - val_mean_absolute_error: 0.0169 - val_acc: 0.9966
# Epoch 689/1000
# 3422/3422 [==============================] - 10s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.0564 - acc: 0.9880 - val_loss: 0.0029 - val_mean_absolute_error: 0.0225 - val_acc: 0.9973
# Epoch 690/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0506 - acc: 0.9942 - val_loss: 0.0046 - val_mean_absolute_error: 0.0117 - val_acc: 0.9945
# Epoch 691/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0519 - acc: 0.9924 - val_loss: 0.0034 - val_mean_absolute_error: 0.0235 - val_acc: 0.9966
# Epoch 692/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0516 - acc: 0.9927 - val_loss: 0.0020 - val_mean_absolute_error: 0.0166 - val_acc: 0.9986
# Epoch 693/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0516 - acc: 0.9947 - val_loss: 0.0026 - val_mean_absolute_error: 0.0248 - val_acc: 0.9980
# Epoch 694/1000
# 3422/3422 [==============================] - 9s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0506 - acc: 0.9942 - val_loss: 0.0018 - val_mean_absolute_error: 0.0104 - val_acc: 0.9986

# %% [markdown]
# # Visualize Training Errors #

# %%
def plot_error(train_errors, val_errors, xlabel, ylabel, title=None, legend=None):
    plt.figure(figsize=(8, 8))
    plt.plot(train_errors)
    plt.plot(val_errors)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.legend(legend, loc='best')
    plt.show()

# %%
# Plot training & validation mean absolute values
plot_error(history.history['mean_absolute_error'], history.history['val_mean_absolute_error'], 'Epoch', 
           'Mean Absolute Error', 'Model Mean Absolute Error', ['Train', 'Validation'])

# %%
# Plot training & validation loss values
plot_error(history.history['loss'], history.history['val_loss'], 'Epoch', 'Loss', 'Model Loss', ['Train', 'Validation'])

# %%
# Plot training & validation accuracy values
plot_error(history.history['acc'], history.history['val_acc'], 'Epoch', 'Accuracy', 'Model Accuracy', ['Train', 'Validation'])

# %% [markdown]
# # Make predictions #
#
# Predictions will be rounded to their nearest units so as to easily compare with the test dataset's wine quality. The neural network predictions are returned as an array of arrays. These will be reshaped to a 1D array of predictions so that they can be compared with their ground-truth values (`y_test`).

# %%
predictions = model.predict(X_test)
predictions = np.reshape(predictions, predictions.shape[0])
predictions = np.round(predictions)

# %% [markdown]
# # Evaluate the model #

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, np.round(predictions))
print('R2 Score: %.3f' % r2)
# Out:
# R2 Score: 0.998

# %% [markdown]
# The plot below compares the predictions of the model with the corresponding ground-truth values.

# %%
def evaluation_plot(y_test, predictions):
    plt.figure(figsize=(10, 8))

    # Density plot of the final predictions and the test values
    sns.kdeplot(predictions, label='Model Predictions')
    sns.kdeplot(y_test, label='Test Values')

    # Label the plot
    plt.xlabel('Quality')
    plt.ylabel('Density')
    plt.title('Test Values and Predictions')
    plt.show()

evaluation_plot(y_test, np.round(predictions))
